# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, transform
from skimage.color import gray2rgb, rgb2gray
from msc.model.augment import random_score_augmentation

# %%
score = io.imread('msc/generation/sample_score-1.png')/255
score = 1-score[:, :, 3]
# score_resized = transform.resize(score, (416, 416))
score_transformed = random_score_augmentation(score, 416, 416)
fig, axs = plt.subplots(figsize=(10, 20))
axs.imshow(score_transformed, cmap='bone')

# %%
images = np.load('data/preprocessed/quarter_measure_data_images_preprocessed.npy')

# %%
n = np.random.randint(len(images))
plt.imshow(images[n], cmap='bone')
